# %%
import pandas as pd
import os


df = pd.read_csv("DKSalaries.csv")
df = df[["Roster Position", "Name + ID", "Salary", "TeamAbbrev"]]


current_directory = os.getcwd()

# Construct the path to the file in the higher directory
higher_directory = os.path.abspath(
    os.path.join(current_directory, os.pardir, os.pardir)
)
file_in_higher_directory_path = os.path.join(higher_directory, "players.csv")
players = pd.read_csv(file_in_higher_directory_path)

# %%
players.head(5)
# Out:
#    player_id         full_name        position
# 0    1630173  Precious Achiuwa         Forward
# 1     203500      Steven Adams          Center
# 2    1628389       Bam Adebayo  Center-Forward
# 3    1630534      Ochai Agbaji           Guard
# 4    1630583      Santi Aldama  Forward-Center

# %%
df = df[df["Name + ID"] != "Juan Toscano-Anderson (32207033)"]
df = df[df["Name + ID"] != "Brandon Williams (32207055)"]
df = df[df["Name + ID"] != "Shaquille Harrison (32207120)"]
df = df[df["Name + ID"] != "Vit Krejci (32207155)"]
df = df[df["Name + ID"] != "Jontay Porter (32207063)"]

# %%
df = df[df["Name + ID"] != "Steven Adams (32207132)"]
df = df[df["Name + ID"] != "Jose Alvarado (32206852)"]
df = df[df["Name + ID"] != "Goga Bitadze (32206683)"]
df = df[df["Name + ID"] != "Anthony Black (32206791)"]
df = df[df["Name + ID"] != "Bol Bol (32206873)"]
df = df[df["Name + ID"] != "Alec Burks (32206723)"]
df = df[df["Name + ID"] != "Vlatko Cancar (32207003)"]
df = df[df["Name + ID"] != "Wendell Carter Jr. (32206699)"]
df = df[df["Name + ID"] != "Jaylen Clark (32207201)"]
df = df[df["Name + ID"] != "Brandon Clarke (32207134)"]
df = df[df["Name + ID"] != "Luka Doncic (32206478)"]
df = df[df["Name + ID"] != "Brandon Clarke (32207134)"]
df = df[df["Name + ID"] != "Kevin Durant (32206488)"]
df = df[df["Name + ID"] != "Dante Exum (32206641)"]
df = df[df["Name + ID"] != "Markelle Fultz (32206716)"]
df = df[df["Name + ID"] != "Eric Gordon (32206709)"]
df = df[df["Name + ID"] != "Draymond Green (32206658)"]
df = df[df["Name + ID"] != "Mouhamed Gueye (32207158)"]
df = df[df["Name + ID"] != "Gary Harris (32206820)"]
df = df[df["Name + ID"] != "Richaun Holmes (32207058)"]
df = df[df["Name + ID"] != "De'Andre Hunter (32206685)"]
df = df[df["Name + ID"] != "Joe Ingles (32206876)"]
df = df[df["Name + ID"] != "Jonathan Isaac (32206804)"]
df = df[df["Name + ID"] != "Maxi Kleber (32207060)"]
df = df[df["Name + ID"] != "Christian Koloko (32207093)"]
df = df[df["Name + ID"] != "Vit Krejci (32207155)"]
df = df[df["Name + ID"] != "Jonathan Kuminga (32206655)"]
df = df[df["Name + ID"] != "Damion Lee (32207018)"]
df = df[df["Name + ID"] != "Nassir Little (32206953)"]
df = df[df["Name + ID"] != "Dereck Lively II (32206662)"]
df = df[df["Name + ID"] != "Ja Morant (32206491)"]
df = df[df["Name + ID"] != "Markieff Morris (32206921)"]
df = df[df["Name + ID"] != "Monte Morris (32207111)"]
df = df[df["Name + ID"] != "Chris Paul (32206624)"]
df = df[df["Name + ID"] != "Gary Payton II (32206880)"]
df = df[df["Name + ID"] != "Otto Porter Jr. (32207089)"]
df = df[df["Name + ID"] != "Derrick Rose (32206859)"]
df = df[df["Name + ID"] != "Matt Ryan (32207174)"]
df = df[df["Name + ID"] != "Isaiah Stewart (32206705)"]
df = df[df["Name + ID"] != "Julian Strawther (32206888)"]
df = df[df["Name + ID"] != "Gary Trent Jr. (32206741)"]
df = df[df["Name + ID"] != "Stanley Umude (32207108)"]
df = df[df["Name + ID"] != "Franz Wagner (32206544)"]
df = df[df["Name + ID"] != "Vince Williams Jr. (32206834)"]
df = df[df["Name + ID"] != "Grant Williams (32206808)"]
df = df[df["Name + ID"] != "Zion Williamson (32206541)"]

# %%
def appFunc_getID(nameAndID):
    draftking_full_name = nameAndID.split("(")[0].strip().lower()
    filtered_df = players[players["full_name"].str.lower() == draftking_full_name]

    if filtered_df.empty:
        print("No row found for", draftking_full_name)
        return None

    return int(filtered_df.iloc[0]["player_id"])


df["player_id"] = df["Name + ID"].apply(appFunc_getID)
df.head(5)
# Out:
#   Roster Position                    Name + ID  Salary TeamAbbrev  player_id
# 1          C/UTIL      Nikola Jokic (32206481)   11200        DEN     203999
# 2          C/UTIL  Domantas Sabonis (32206483)   10000        SAC    1627734
# 3       PG/G/UTIL        Trae Young (32206485)    9900        ATL    1629027
# 6       PG/G/UTIL      De'Aaron Fox (32206494)    9400        SAC    1628368
# 7    PG/SG/G/UTIL     Stephen Curry (32206497)    9200        GSW     201939

# %%
salary_dict = {}
team_dict = {}

for _, row in df.iterrows():
    salary_dict[row["player_id"]] = row["Salary"]
    team_dict[row["player_id"]] = row["TeamAbbrev"]

# %%
# 1. Make dict of roster positions with players as array
# 2. Generate N random valid lineups
# 3. Simulate, get overall rankings. Keep top 5-10% just as they are (elitism). Use top 25% as sure parents, with rest having 33%?
# 4. Inherit by:
# for each survivor, find M other random survivors. Make X children by randomly deciding traits from parents
# 5. Mutate children by:
# for each child, randomly swap out T players, with T changing over time?
# 6. Add Q purely random lineups
# 6. Save best, repeat 2-6 until satisfied

# %% [markdown]
# ### 1. Make dict of roster positions with players as array

# %%
player_dict = {}
player_dict["PG"] = []
player_dict["SG"] = []
player_dict["SF"] = []
player_dict["PF"] = []
player_dict["C"] = []
player_dict["G"] = []
player_dict["F"] = []
player_dict["UTIL"] = []

for _, row in df.iterrows():
    if "PG" in row["Roster Position"]:
        player_dict["PG"].append(row["player_id"])
    if "SG" in row["Roster Position"]:
        player_dict["SG"].append(row["player_id"])
    if "SF" in row["Roster Position"]:
        player_dict["SF"].append(row["player_id"])
    if "PF" in row["Roster Position"]:
        player_dict["PF"].append(row["player_id"])
    if "C" in row["Roster Position"]:
        player_dict["C"].append(row["player_id"])
    if "G" in row["Roster Position"]:
        player_dict["G"].append(row["player_id"])
    if "F" in row["Roster Position"]:
        player_dict["F"].append(row["player_id"])
    if "UTIL" in row["Roster Position"]:
        player_dict["UTIL"].append(row["player_id"])

len(player_dict["UTIL"])
# Out:
# 164

# %%
from operator import itemgetter


def lineup_is_valid(lineup_array):
    """Assumes that the array of id's has one per correct slot."""
    if len(lineup_array) != 8:  # check is right length
        return False
    if len(set(lineup_array)) != len(lineup_array):  # check for dupes
        return False
    salaries = itemgetter(*lineup_array)(salary_dict)
    if sum(salaries) > 50000:  # check in budget
        return False
    teams = itemgetter(*lineup_array)(team_dict)
    if len(set(teams)) < 2:  # Check if has both teams
        return False
    return True

# %% [markdown]
# ### 2. Generate N random valid lineups

# %%
import math
import random


def generate_n_pure_random_lineups(num_lineups):
    lineups = []
    max_length = num_lineups
    #print(max_length)
    while len(lineups) < max_length:
        pg = random.choice(player_dict["PG"])
        sg = random.choice(player_dict["SG"])
        sf = random.choice(player_dict["SF"])
        pf = random.choice(player_dict["PF"])
        c = random.choice(player_dict["C"])
        g = random.choice(player_dict["G"])
        f = random.choice(player_dict["F"])
        util = random.choice(player_dict["UTIL"])
        new_lineup = [pg, sg, sf, pf, c,g,f,util]
        if lineup_is_valid(new_lineup):
            lineups.append(new_lineup)
    return lineups

generate_n_pure_random_lineups(1)
# Out:
# [[1630177, 202066, 1629667, 203937, 1628991, 1628368, 1630530, 1629643]]

# %% [markdown]
# ### 3. Simulate Trials and get Parents/Elites

# %%
import json
import os


json_file_path = os.path.join(
    higher_directory, "models", "simpledfs.json"
)

with open(json_file_path, "r") as json_file:
    # Load the JSON data into a dictionary
    trials = json.load(json_file)

# %%
import numpy as np


def get_rankings(lineup_array, trials, num_trials):
    # 0. Make an array of length lineup_array to store rankings
    rankings_list = [0] * len(lineup_array)

    # 1. Pick a random draw num (1-2000) FOR EACH PLAYER
    not_in_traces = set()
    for i in range(num_trials):
        #trace_length = len(not_in_traces)
        individual_player_scores = {}
        lineup_scores = {}
        # 2. Make a dict of player:score for that trial
        for player_id in trials.keys():
            individual_player_scores[int(player_id)] = random.choice(trials[player_id])
        # 3. For each lineup, for each player in that lineup add that score to the index in the array
        for j in range(len(lineup_array)):
            curr_lineup = lineup_array[j]
            lineup_score = 0
            for player in curr_lineup:
                if player not in individual_player_scores.keys():
                    not_in_traces.add(player)
                else:
                    lineup_score += individual_player_scores[player]

            lineup_scores[j] = lineup_score

        # 4. Add rankings to rank array
        sorted_scores_list = sorted(
            lineup_scores.items(), key=lambda item: item[1], reverse=True
        )
        counter = 1
        for sorted_score_tuple in sorted_scores_list:
            rankings_list[sorted_score_tuple[0]] += counter
            counter += 1
        #if len(not_in_traces) > trace_length and len(not_in_traces) > 0:
        #    print("No trace for following:", not_in_traces)

    # 5. Return rankings array

    return rankings_list


def get_parents(
    lineup_array, ranking_list, sure_parent_percent, possible_parent_percent
):
    # Get sure parent percentile of rankings
    threshold_value = np.percentile(ranking_list, sure_parent_percent)

    # Find indices of values above the threshold
    indices_above_threshold = list(np.where(ranking_list > threshold_value)[0])

    # get indices of all rankings below (?) that percentile, add to array
    indices_below_threshold = list(np.where(ranking_list <= threshold_value)[0])

    # for indices not in that list, if random num > possible_parent_percent, add to array
    for index in indices_below_threshold:
        decider = random.random()
        if decider < possible_parent_percent:
            indices_above_threshold.append(index)

    # return array
    selected_lineups = [lineup_array[i] for i in indices_above_threshold]
    return selected_lineups

# %% [markdown]
# ### 4. Inherit

# %%
def make_children(survivor_lineups, num_children):
    children_lineups = []

    # while len(children) < num_children
    while len(children_lineups) < num_children:
        # pick two random survivors
        first_parent = random.choice(survivor_lineups)
        second_parent = random.choice(survivor_lineups)
        # for each position, randomly pick between the two parents
        child_lineup = [0] * len(first_parent)
        for player_position in range(len(first_parent)):
            child_lineup[player_position] = random.choice(
                [first_parent[player_position], second_parent[player_position]]
            )
    # if not a valid thing, continue
        if lineup_is_valid(child_lineup):
            children_lineups.append(child_lineup)
            
    return children_lineups

# %% [markdown]
# ### 5. Mutate

# %%
def mutate_children(children_lineups, num_mutations, percent_mutated):
    # sample percent_mutated children
    num_elements_to_sample = int(percent_mutated * len(children_lineups))
    random_child_lineups = random.sample(children_lineups, num_elements_to_sample)
    out_children = [lst for lst in children_lineups if lst not in random_child_lineups]
    # for each, add num_mutations. If not valid, try another set of mutations until it does.
    for child in random_child_lineups:
        temp_child = child
        for i in range(num_mutations):
            position_to_mutate = random.randint(0, len(child) - 1)
            if position_to_mutate == 0:
                temp_child[position_to_mutate] = random.choice(player_dict["PG"])
            if position_to_mutate == 1:
                temp_child[position_to_mutate] = random.choice(player_dict["SG"])
            if position_to_mutate == 2:
                temp_child[position_to_mutate] = random.choice(player_dict["SF"])
            if position_to_mutate == 3:
                temp_child[position_to_mutate] = random.choice(player_dict["PF"])
            if position_to_mutate == 4:
                temp_child[position_to_mutate] = random.choice(player_dict["C"])
            if position_to_mutate == 5:
                temp_child[position_to_mutate] = random.choice(player_dict["G"])
            if position_to_mutate == 6:
                temp_child[position_to_mutate] = random.choice(player_dict["F"])
            if position_to_mutate == 7:
                temp_child[position_to_mutate] = random.choice(player_dict["UTIL"])

            while not lineup_is_valid(temp_child):
                temp_child = child
                if position_to_mutate == 0:
                    temp_child[position_to_mutate] = random.choice(player_dict["PG"])
                if position_to_mutate == 1:
                    temp_child[position_to_mutate] = random.choice(player_dict["SG"])
                if position_to_mutate == 2:
                    temp_child[position_to_mutate] = random.choice(player_dict["SF"])
                if position_to_mutate == 3:
                    temp_child[position_to_mutate] = random.choice(player_dict["PF"])
                if position_to_mutate == 4:
                    temp_child[position_to_mutate] = random.choice(player_dict["C"])
                if position_to_mutate == 5:
                    temp_child[position_to_mutate] = random.choice(player_dict["G"])
                if position_to_mutate == 6:
                    temp_child[position_to_mutate] = random.choice(player_dict["F"])
                if position_to_mutate == 7:
                    temp_child[position_to_mutate] = random.choice(player_dict["UTIL"])

        out_children.append(temp_child)
    # return mutated children
    return out_children

# %% [markdown]
# ## Evolution

# %%
best_lineups = {}


def run_ga(
    num_gens,
    num_trials,
    sure_parent_percent,
    possible_parent_percent,
    num_mutations,
    percent_mutated,
):
    # random start
    population = generate_n_pure_random_lineups(100)
    GOAT_lineups = []
    # for num_gens
    for i in range(1, num_gens + 1):
        # run get rankings on pop
        rankings_by_index = get_rankings(population, trials, num_trials)
        # save best 2? in best_lineups[gen_num] = [[...],[...]], or csv
        indices_of_highest_values = np.argsort(rankings_by_index)[-2:]
        best_lineups[i] = {
            rankings_by_index[indices_of_highest_values[0]]: population[
                indices_of_highest_values[0]
            ],
            rankings_by_index[indices_of_highest_values[1]]: population[
                indices_of_highest_values[1]
            ],
        }
        GOAT_lineups.append(population[indices_of_highest_values[0]])
        GOAT_lineups.append(population[indices_of_highest_values[1]])
        # print best ranking
        if i % 250 == 0:
            print(
                "Best score of gen",
                i,
                "is",
                rankings_by_index[indices_of_highest_values[0]],
            )
        # run make children
        parents = get_parents(
            population, rankings_by_index, sure_parent_percent, possible_parent_percent
        )
        num_children = int(1.0 / (i + 1) * 100)
        num_random = 100 - num_children
        children = make_children(parents, num_children)

        # run mutate children
        mutated_children = mutate_children(children, num_mutations, percent_mutated)

        # add random for the rest
        new_random_kids = generate_n_pure_random_lineups(num_random)

        # reset population
        population = mutated_children + new_random_kids
    # return best of the best

    GOAT_rankings = get_rankings(GOAT_lineups, trials, num_trials)
    GOAT_score_pairs = list(zip(GOAT_lineups, GOAT_rankings))
    sorted_pairs = sorted(GOAT_score_pairs, key=lambda pair: pair[1], reverse=True)

    # Print player IDs in order of scores in reverse order
    counter = 0
    for lineup, score in sorted_pairs[-5:]:
        print(f"Lineup: {lineup}, Score: {score}")

# %%
num_gens = 5000
num_trials = 50
sure_parent_percent = 20
possible_parent_percent = 0.33
num_mutations = 2
percent_mutated = 0.6


for i in range(20):
    print("ECOSYSTEM", i)
    best_lineups = {}
    run_ga(
        num_gens,
        num_trials,
        sure_parent_percent,
        possible_parent_percent,
        num_mutations,
        percent_mutated,
    )
# Out:
# ECOSYSTEM 0
# Best score of gen 250 is 4882
# Best score of gen 500 is 4780
# Best score of gen 750 is 4910
# Best score of gen 1000 is 4874
# Best score of gen 1250 is 4761
# Best score of gen 1500 is 4895
# Best score of gen 1750 is 4781
# Best score of gen 2000 is 4901
# Best score of gen 2250 is 4885
# Best score of gen 2500 is 4871
# Best score of gen 2750 is 4748
# Best score of gen 3000 is 4816
# Best score of gen 3250 is 4839
# Best score of gen 3500 is 4794
# Best score of gen 3750 is 4946
# Best score of gen 4000 is 4819
# Best score of gen 4250 is 4769
# Best score of gen 4500 is 4907
# Best score of gen 4750 is 4579
# Best score of gen 5000 is 4817
# Lineup: [1630165, 1641732, 1628972, 1630533, 1630568, 201988, 1630183, 1629678], Score: 35761
# Lineup: [1631221, 1630558, 1630587, 1631159, 1629234, 1641732, 1630556, 1630595], Score: 33243
# Lineup: [1630692, 1630530, 1630700, 1631197, 1630526, 1629003, 1631223, 1641711], Score: 30454
# Lineup: [1630227, 1630537, 1629010, 1641771, 1629643, 1628989, 203967, 1641765], Score: 30334
# Lineup: [1631311, 1627749, 1631100, 1641713, 203939, 202066, 1628972, 1630182], Score: 20949
# ECOSYSTEM 1
# Best score of gen 250 is 4837
# Best score of gen 500 is 4917
# Best score of gen 750 is 4876
# Best score of gen 1000 is 4836
# Best score of gen 1250 is 4776
# Best score of gen 1500 is 4871
# Best score of gen 1750 is 4887
# Best score of gen 2000 is 4762
# Best score of gen 2250 is 4855
# Best score of gen 2500 is 4937
# Best score of gen 2750 is 4929
# Best score of gen 3000 is 4901
# Best score of gen 3250 is 4825
# Best score of gen 3500 is 4879
# Best score of gen 3750 is 4905
# Best score of gen 4000 is 4914
# Best score of gen 4250 is 4835
# Best score of gen 4500 is 4821
# Best score of gen 4750 is 4882
# Best score of gen 5000 is 4723
# Lineup: [1631165, 203471, 202066, 1631099, 1628962, 1631169, 203937, 1641754], Score: 33317
# Lineup: [1641723, 1628370, 1631220, 1628995, 1631218, 1627750, 203501, 1630604], Score: 30326
# Lineup: [1629618, 1641722, 1629628, 1630535, 1629002, 1631220, 1629675, 1641806], Score: 27339
# Lineup: [1631241, 1627742, 1641711, 1630230, 1626172, 203200, 1626168, 1641723], Score: 27202
# Lineup: [203552, 1628972, 1628995, 1629021, 1629002, 1641722, 1626168, 1641771], Score: 24167
# ECOSYSTEM 2
# Best score of gen 250 is 4907
# Best score of gen 500 is 4865
# Best score of gen 750 is 4840
# Best score of gen 1000 is 4781
# Best score of gen 1250 is 4957
# Best score of gen 1500 is 4819
# Best score of gen 1750 is 4831
# Best score of gen 2000 is 4809
# Best score of gen 2250 is 4910
# Best score of gen 2500 is 4776
# Best score of gen 2750 is 4919
# Best score of gen 3000 is 4941
# Best score of gen 3250 is 4722
# Best score of gen 3500 is 4822
# Best score of gen 3750 is 4771
# Best score of gen 4000 is 4854
# Best score of gen 4250 is 4808
# Best score of gen 4500 is 4830
# Best score of gen 4750 is 4858
# Best score of gen 5000 is 4930
# Lineup: [201988, 1630639, 1629139, 1630556, 1628981, 1630175, 203937, 1628426], Score: 31115
# Lineup: [1631093, 1641732, 1627884, 1631159, 1630568, 1630692, 1630556, 1630164], Score: 29543
# Lineup: [1629618, 1627749, 1628966, 1630230, 1629021, 1630184, 1629010, 1630586], Score: 29248
# Lineup: [1630240, 1630639, 1629008, 1627884, 1629021, 1630692, 1631216, 1630541], Score: 23608
# Lineup: [1630193, 1631220, 1628972, 1629675, 1630604, 1641722, 1629006, 201988], Score: 12841
# ECOSYSTEM 3
# Best score of gen 250 is 4892
# Best score of gen 500 is 4852
# Best score of gen 750 is 4901
# Best score of gen 1000 is 4821
# Best score of gen 1250 is 4827
# Best score of gen 1500 is 4943
# Best score of gen 1750 is 4901
# Best score of gen 2000 is 4884
# Best score of gen 2250 is 4959
# Best score of gen 2500 is 4876
# Best score of gen 2750 is 4937
# Best score of gen 3000 is 4927
# Best score of gen 3250 is 4962
# Best score of gen 3500 is 4853
# Best score of gen 3750 is 4922
# Best score of gen 4000 is 4843
# Best score of gen 4250 is 4791
# Best score of gen 4500 is 4873
# Best score of gen 4750 is 4890
# Best score of gen 5000 is 4872
# Lineup: [1631221, 1629003, 1641816, 1630182, 202685, 203484, 1631197, 1630692], Score: 30426
# Lineup: [1630227, 1630541, 1631216, 203967, 1628963, 1631111, 1641709, 1630284], Score: 26545
# Lineup: [1630259, 1641754, 1630639, 1631094, 1628962, 1630240, 202711, 202687], Score: 21429
# Lineup: [203552, 1631169, 1630587, 1630296, 1630192, 1630162, 1631223, 1631111], Score: 19882
# Lineup: [1630591, 1628989, 202066, 1630296, 1628981, 1630243, 1630535, 1629667], Score: 17161
# ECOSYSTEM 4
# Best score of gen 250 is 4908
# Best score of gen 500 is 4914
# Best score of gen 750 is 4723
# Best score of gen 1000 is 4834
# Best score of gen 1250 is 4806
# Best score of gen 1500 is 4853
# Best score of gen 1750 is 4871
# Best score of gen 2000 is 4962
# Best score of gen 2250 is 4871
# Best score of gen 2500 is 4876
# Best score of gen 2750 is 4760
# Best score of gen 3000 is 4842
# Best score of gen 3250 is 4887
# Best score of gen 3500 is 4874
# Best score of gen 3750 is 4921
# Best score of gen 4000 is 4933
# Best score of gen 4250 is 4837
# Best score of gen 4500 is 4924
# Best score of gen 4750 is 4799
# Best score of gen 5000 is 4897
# Lineup: [201144, 1641732, 1628426, 1630182, 1628962, 1641724, 203952, 1630643], Score: 35385
# Lineup: [1631165, 203501, 1628972, 1630552, 1630604, 1630284, 1630583, 203084], Score: 33228
# Lineup: [1631221, 1631220, 1628995, 1630533, 203939, 1628989, 1641709, 1641806], Score: 30730
# Lineup: [1629003, 203200, 1630537, 1630533, 1628981, 1630240, 1631222, 1628379], Score: 27117
# Lineup: [1630243, 1641764, 1630533, 1631212, 1630586, 203925, 1631100, 201988], Score: 25849
# ECOSYSTEM 5
# Best score of gen 250 is 4906
# Best score of gen 500 is 4870
# Best score of gen 750 is 4926
# Best score of gen 1000 is 4834
# Best score of gen 1250 is 4903
# Best score of gen 1500 is 4886
# Best score of gen 1750 is 4871
# Best score of gen 2000 is 4877
# Best score of gen 2250 is 4848
# Best score of gen 2500 is 4823
# Best score of gen 2750 is 4804
# Best score of gen 3000 is 4839
# Best score of gen 3250 is 4876
# Best score of gen 3500 is 4945
# Best score of gen 3750 is 4849
# Best score of gen 4000 is 4832
# Best score of gen 4250 is 4763
# Best score of gen 4500 is 4853
# Best score of gen 4750 is 4894
# Best score of gen 5000 is 4731
# Lineup: [1630184, 1629003, 1631128, 1631223, 1627783, 1630541, 1631216, 1630243], Score: 24342
# Lineup: [1631221, 1628379, 1630217, 1626168, 1630604, 1630639, 1630183, 1630177], Score: 23831
# Lineup: [1630692, 1630541, 1629678, 1641816, 1631212, 1631100, 1629628, 203484], Score: 23765
# Lineup: [1629162, 1626164, 1641816, 1630611, 201580, 1630591, 1631159, 1641713], Score: 21804
# Lineup: [203468, 1641754, 1629667, 1641713, 1629021, 1628379, 1631220, 203458], Score: 20933
# ECOSYSTEM 6
# Best score of gen 250 is 4876
# Best score of gen 500 is 4614
# Best score of gen 750 is 4861
# Best score of gen 1000 is 4886
# Best score of gen 1250 is 4762
# Best score of gen 1500 is 4914
# Best score of gen 1750 is 4904
# Best score of gen 2000 is 4726
# Best score of gen 2250 is 4818
# Best score of gen 2500 is 4889
# Best score of gen 2750 is 4818
# Best score of gen 3000 is 4878
# Best score of gen 3250 is 4787
# Best score of gen 3500 is 4815
# Best score of gen 3750 is 4801
# Best score of gen 4000 is 4930
# Best score of gen 4250 is 4925
# Best score of gen 4500 is 4882
# Best score of gen 4750 is 4901
# Best score of gen 5000 is 4893
# Lineup: [1641723, 202691, 1627742, 1641771, 1630643, 1630227, 1629726, 1630235], Score: 36034
# Lineup: [1628368, 1641732, 1630587, 1631197, 1627751, 1630702, 1631220, 1628981], Score: 33294
# Lineup: [203935, 1631128, 1641765, 1631223, 203458, 1641732, 1629638, 1630240], Score: 31661
# Lineup: [1630558, 1641711, 202083, 1628995, 1626172, 1628960, 1630296, 1630541], Score: 28458
# Lineup: [1630702, 1630537, 1629139, 1641709, 1630568, 203935, 1641816, 1630284], Score: 28189
# ECOSYSTEM 7
# Best score of gen 250 is 4909
# Best score of gen 500 is 4787
# Best score of gen 750 is 4880
# Best score of gen 1000 is 4759
# Best score of gen 1250 is 4866
# Best score of gen 1500 is 4960
# Best score of gen 1750 is 4763
# Best score of gen 2000 is 4711
# Best score of gen 2250 is 4972
# Best score of gen 2500 is 4890
# Best score of gen 2750 is 4897
# Best score of gen 3000 is 4934
# Best score of gen 3250 is 4941
# Best score of gen 3500 is 4911
# Best score of gen 3750 is 4892
# Best score of gen 4000 is 4913
# Best score of gen 4250 is 4882
# Best score of gen 4500 is 4762
# Best score of gen 4750 is 4948
# Best score of gen 5000 is 4905
# Lineup: [1630558, 203471, 1630700, 1641816, 1630164, 1641732, 1641709, 1641724], Score: 34872
# Lineup: [1630243, 1631169, 1630611, 1630168, 1630214, 1630567, 1628426, 1628962], Score: 32729
# Lineup: [202709, 203925, 1630533, 1630587, 203991, 1630227, 1641711, 1641732], Score: 30152
# Lineup: [1631204, 1628379, 1630541, 1629139, 1628449, 203552, 1641816, 1628370], Score: 26599
# Lineup: [1629618, 1630591, 1628960, 1631159, 203994, 1629726, 1629002, 1641713], Score: 23825
# ECOSYSTEM 8
# Best score of gen 250 is 4705
# Best score of gen 500 is 4755
# Best score of gen 750 is 4805
# Best score of gen 1000 is 4863
# Best score of gen 1250 is 4926
# Best score of gen 1500 is 4858
# Best score of gen 1750 is 4869
# Best score of gen 2000 is 4873
# Best score of gen 2250 is 4932
# Best score of gen 2500 is 4731
# Best score of gen 2750 is 4843
# Best score of gen 3000 is 4943
# Best score of gen 3250 is 4891
# Best score of gen 3500 is 4801
# Best score of gen 3750 is 4744
# Best score of gen 4000 is 4762
# Best score of gen 4250 is 4764
# Best score of gen 4500 is 4749
# Best score of gen 4750 is 4926
# Best score of gen 5000 is 4902
# Lineup: [1630700, 1630193, 1641724, 1628995, 1630586, 1641723, 1628991, 1630227], Score: 32053
# Lineup: [1630184, 1629638, 1628966, 1627884, 1629234, 1641711, 1630533, 203967], Score: 32018
# Lineup: [1628368, 1641754, 1629638, 1630611, 1627751, 1641724, 1631222, 1630702], Score: 29636
# Lineup: [1630259, 1628379, 1630700, 1631222, 1630643, 1628368, 1641771, 203200], Score: 29085
# Lineup: [1630227, 203078, 1641816, 1630552, 1630192, 1631367, 203937, 1629726], Score: 22095
# ECOSYSTEM 9
# Best score of gen 250 is 4739
# Best score of gen 500 is 4885
# Best score of gen 750 is 4836
# Best score of gen 1000 is 4811
# Best score of gen 1250 is 4859
# Best score of gen 1500 is 4784
# Best score of gen 1750 is 4892
# Best score of gen 2000 is 4760
# Best score of gen 2250 is 4713
# Best score of gen 2500 is 4934
# Best score of gen 2750 is 4888
# Best score of gen 3000 is 4861
# Best score of gen 3250 is 4859
# Best score of gen 3500 is 4921
# Best score of gen 3750 is 4786
# Best score of gen 4000 is 4810
# Best score of gen 4250 is 4800
# Best score of gen 4500 is 4864
# Best score of gen 4750 is 4905
# Best score of gen 5000 is 4935
# Lineup: [1631241, 1629628, 1629139, 1641765, 202685, 1630558, 1631223, 1641723], Score: 40998
# Lineup: [1631165, 1628972, 1627884, 1641713, 1626157, 1631221, 1630587, 1631159], Score: 40735
# Lineup: [1631165, 203200, 1631216, 1631197, 1629002, 1631221, 1627783, 203484], Score: 33928
# Lineup: [1630243, 202083, 1628426, 1629139, 1630526, 1631128, 203200, 1630182], Score: 33646
# Lineup: [1630702, 1630591, 1630533, 1629139, 201599, 1641754, 1630552, 1631221], Score: 30942
# ECOSYSTEM 10
# Best score of gen 250 is 4943
# Best score of gen 500 is 4879
# Best score of gen 750 is 4830
# Best score of gen 1000 is 4853
# Best score of gen 1250 is 4878
# Best score of gen 1500 is 4875
# Best score of gen 1750 is 4755
# Best score of gen 2000 is 4811
# Best score of gen 2250 is 4931
# Best score of gen 2500 is 4864
# Best score of gen 2750 is 4818
# Best score of gen 3000 is 4869
# Best score of gen 3250 is 4716
# Best score of gen 3500 is 4815
# Best score of gen 3750 is 4893
# Best score of gen 4000 is 4900
# Best score of gen 4250 is 4833
# Best score of gen 4500 is 4892
# Best score of gen 4750 is 4887
# Best score of gen 5000 is 4809
# Lineup: [1631241, 1630217, 1641709, 1630182, 1629021, 1630259, 1630535, 1631128], Score: 35143
# Lineup: [1630227, 1628972, 1629723, 1628426, 1630586, 1631204, 1627884, 1629675], Score: 34452
# Lineup: [1631367, 1631128, 1629638, 1641771, 1629675, 1630284, 1630182, 1641709], Score: 33377
# Lineup: [1631241, 1628989, 1631216, 1641709, 1629643, 203925, 1629002, 1629618], Score: 33293
# Lineup: [1630700, 1631220, 202066, 1630587, 1629675, 1641723, 1631094, 1630259], Score: 31266
# ECOSYSTEM 11
# Best score of gen 250 is 4883
# Best score of gen 500 is 4897
# Best score of gen 750 is 4880
# Best score of gen 1000 is 4890
# Best score of gen 1250 is 4852
# Best score of gen 1500 is 4862
# Best score of gen 1750 is 4668
# Best score of gen 2000 is 4923
# Best score of gen 2250 is 4867
# Best score of gen 2500 is 4853
# Best score of gen 2750 is 4879
# Best score of gen 3000 is 4841
# Best score of gen 3250 is 4885
# Best score of gen 3500 is 4947
# Best score of gen 3750 is 4874
# Best score of gen 4000 is 4846
# Best score of gen 4250 is 4827
# Best score of gen 4500 is 4960
# Best score of gen 4750 is 4782
# Best score of gen 5000 is 4935
# Lineup: [1630227, 203471, 1628966, 1641713, 1629234, 1631165, 1629006, 1630537], Score: 32596
# Lineup: [1630591, 1630537, 1630611, 1630552, 1630214, 1629638, 1630583, 1641816], Score: 28864
# Lineup: [1629162, 1631204, 1627884, 201152, 1630214, 1630259, 1641711, 203939], Score: 28179
# Lineup: [1631241, 1631093, 1628989, 1631099, 1630586, 1630243, 1629139, 1630235], Score: 25889
# Lineup: [1630240, 203078, 1629010, 1629002, 1631218, 1631111, 1629643, 1631165], Score: 24523
# ECOSYSTEM 12
# Best score of gen 250 is 4940
# Best score of gen 500 is 4879
# Best score of gen 750 is 4873
# Best score of gen 1000 is 4843
# Best score of gen 1250 is 4922
# Best score of gen 1500 is 4869
# Best score of gen 1750 is 4684
# Best score of gen 2000 is 4864
# Best score of gen 2250 is 4830
# Best score of gen 2500 is 4904
# Best score of gen 2750 is 4877
# Best score of gen 3000 is 4746
# Best score of gen 3250 is 4763
# Best score of gen 3500 is 4911
# Best score of gen 3750 is 4822
# Best score of gen 4000 is 4926
# Best score of gen 4250 is 4839
# Best score of gen 4500 is 4802
# Best score of gen 4750 is 4800
# Best score of gen 5000 is 4692
# Lineup: [1627750, 1641711, 1630183, 1630182, 1630164, 1630284, 1631220, 1641765], Score: 40348
# Lineup: [1630184, 203471, 1641711, 203937, 1631212, 1630259, 203992, 1641771], Score: 40002
# Lineup: [1631241, 1629723, 1641711, 1630230, 1631105, 1641754, 1629021, 1630180], Score: 32407
# Lineup: [1631204, 1631220, 1627884, 1630230, 1631159, 1630700, 1629008, 1631367], Score: 31353
# Lineup: [1641806, 1631169, 1629667, 1629021, 201152, 1631111, 1628989, 1631100], Score: 29418
# ECOSYSTEM 13
# Best score of gen 250 is 4900
# Best score of gen 500 is 4838
# Best score of gen 750 is 4900
# Best score of gen 1000 is 4902
# Best score of gen 1250 is 4893
# Best score of gen 1500 is 4903
# Best score of gen 1750 is 4717
# Best score of gen 2000 is 4853
# Best score of gen 2250 is 4848
# Best score of gen 2500 is 4919
# Best score of gen 2750 is 4747
# Best score of gen 3000 is 4749
# Best score of gen 3250 is 4865
# Best score of gen 3500 is 4882
# Best score of gen 3750 is 4956
# Best score of gen 4000 is 4813
# Best score of gen 4250 is 4896
# Best score of gen 4500 is 4945
# Best score of gen 4750 is 4915
# Best score of gen 5000 is 4916
# Lineup: [202704, 203925, 1629638, 1630552, 1629002, 1641754, 1626168, 1641711], Score: 32636
# Lineup: [1631165, 1631100, 1641724, 1641713, 1630164, 203468, 1631212, 203458], Score: 32593
# Lineup: [1629162, 1641724, 1630183, 1629021, 1631212, 1629003, 1630556, 1629675], Score: 30708
# Lineup: [203471, 1631111, 1630217, 1629139, 1629643, 1641732, 1629678, 1629002], Score: 19333
# Lineup: [201988, 1629726, 1630530, 1630168, 1629234, 1630240, 1630541, 1629139], Score: 18568
# ECOSYSTEM 14
# Best score of gen 250 is 4794
# Best score of gen 500 is 4765
# Best score of gen 750 is 4833
# Best score of gen 1000 is 4884
# Best score of gen 1250 is 4730
# Best score of gen 1500 is 4874
# Best score of gen 1750 is 4895
# Best score of gen 2000 is 4865
# Best score of gen 2250 is 4821
# Best score of gen 2500 is 4844
# Best score of gen 2750 is 4949
# Best score of gen 3000 is 4884
# Best score of gen 3250 is 4851
# Best score of gen 3500 is 4836
# Best score of gen 3750 is 4862
# Best score of gen 4000 is 4782
# Best score of gen 4250 is 4800
# Best score of gen 4500 is 4787
# Best score of gen 4750 is 4856
# Best score of gen 5000 is 4963
# Lineup: [1641806, 202066, 1630611, 1630583, 1627751, 202691, 1631197, 1629618], Score: 26089
# Lineup: [203552, 1631220, 1628426, 1630587, 1629675, 202066, 1628972, 1626172], Score: 21536
# Lineup: [1630700, 202691, 1630533, 1631159, 1627751, 1641723, 1629678, 1629638], Score: 21016
# Lineup: [203078, 1641724, 1630608, 1630529, 202685, 1631165, 1631216, 1630259], Score: 18396
# Lineup: [1630227, 1630537, 1630529, 1630611, 1631105, 1630235, 1641765, 1630164], Score: 17663
# ECOSYSTEM 15
# Best score of gen 250 is 4880
# Best score of gen 500 is 4733
# Best score of gen 750 is 4920
# Best score of gen 1000 is 4936
# Best score of gen 1250 is 4955
# Best score of gen 1500 is 4838
# Best score of gen 1750 is 4847
# Best score of gen 2000 is 4806
# Best score of gen 2250 is 4966
# Best score of gen 2500 is 4842
# Best score of gen 2750 is 4896
# Best score of gen 3000 is 4851
# Best score of gen 3250 is 4766
# Best score of gen 3500 is 4826
# Best score of gen 3750 is 4905
# Best score of gen 4000 is 4883
# Best score of gen 4250 is 4842
# Best score of gen 4500 is 4905
# Best score of gen 4750 is 4891
# Best score of gen 5000 is 4807
# Lineup: [1630692, 203200, 1629008, 1629667, 203939, 1631221, 1641816, 1630296], Score: 36381
# Lineup: [1631165, 1630702, 1631216, 1626157, 1631218, 1641724, 1630608, 1629643], Score: 34818
# Lineup: [1629618, 203484, 1631216, 1641765, 1630604, 203925, 1631094, 1628426], Score: 33968
# Lineup: [1630700, 1641722, 1630587, 1641816, 1630168, 1631221, 1631100, 203935], Score: 32974
# Lineup: [1626164, 1630702, 1630541, 1630296, 1630604, 1641722, 1629726, 1641711], Score: 26234
# ECOSYSTEM 16
# Best score of gen 250 is 4783
# Best score of gen 500 is 4836
# Best score of gen 750 is 4805
# Best score of gen 1000 is 4821
# Best score of gen 1250 is 4912
# Best score of gen 1500 is 4758
# Best score of gen 1750 is 4799
# Best score of gen 2000 is 4894
# Best score of gen 2250 is 4787
# Best score of gen 2500 is 4858
# Best score of gen 2750 is 4736
# Best score of gen 3000 is 4928
# Best score of gen 3250 is 4753
# Best score of gen 3500 is 4891
# Best score of gen 3750 is 4853
# Best score of gen 4000 is 4889
# Best score of gen 4250 is 4829
# Best score of gen 4500 is 4912
# Best score of gen 4750 is 4861
# Best score of gen 5000 is 4859
# Lineup: [1630591, 1629628, 1641816, 1628426, 1626172, 1630177, 1630608, 1630586], Score: 33227
# Lineup: [1630259, 1628989, 1629006, 201152, 1630192, 1631165, 1630230, 1628962], Score: 30933
# Lineup: [1631221, 1631169, 203200, 203967, 1628449, 1629638, 1630611, 203458], Score: 30560
# Lineup: [1630235, 202083, 1641816, 1627884, 1628449, 1631100, 1630529, 1631128], Score: 30314
# Lineup: [1630184, 1629003, 203200, 1641816, 1631218, 1627750, 1631216, 1629723], Score: 30084
# ECOSYSTEM 17
# Best score of gen 250 is 4917
# Best score of gen 500 is 4815
# Best score of gen 750 is 4773
# Best score of gen 1000 is 4900
# Best score of gen 1250 is 4886
# Best score of gen 1500 is 4803
# Best score of gen 1750 is 4803
# Best score of gen 2000 is 4898
# Best score of gen 2250 is 4752
# Best score of gen 2500 is 4804
# Best score of gen 2750 is 4941
# Best score of gen 3000 is 4684
# Best score of gen 3250 is 4946
# Best score of gen 3500 is 4814
# Best score of gen 3750 is 4884
# Best score of gen 4000 is 4847
# Best score of gen 4250 is 4811
# Best score of gen 4500 is 4758
# Best score of gen 4750 is 4767
# Best score of gen 5000 is 4947
# Lineup: [1641723, 1641724, 1631220, 203952, 1631212, 1628379, 203200, 203967], Score: 32096
# Lineup: [1630235, 203552, 1630533, 1628966, 1630164, 1630259, 1641771, 203952], Score: 31510
# Lineup: [1631367, 1641722, 202066, 1641771, 1631105, 201988, 1641816, 1629675], Score: 30495
# Lineup: [1631367, 1630558, 1631100, 1641771, 1630604, 1630177, 1630296, 1630567], Score: 27244
# Lineup: [203935, 1641724, 1630611, 1630535, 1627734, 1628379, 1631222, 1630296], Score: 18313
# ECOSYSTEM 18
# Best score of gen 250 is 4822
# Best score of gen 500 is 4939
# Best score of gen 750 is 4808
# Best score of gen 1000 is 4884
# Best score of gen 1250 is 4953
# Best score of gen 1500 is 4742
# Best score of gen 1750 is 4890
# Best score of gen 2000 is 4820
# Best score of gen 2250 is 4918
# Best score of gen 2500 is 4770
# Best score of gen 2750 is 4807
# Best score of gen 3000 is 4795
# Best score of gen 3250 is 4923
# Best score of gen 3500 is 4784
# Best score of gen 3750 is 4797
# Best score of gen 4000 is 4920
# Best score of gen 4250 is 4907
# Best score of gen 4500 is 4857
# Best score of gen 4750 is 4815
# Best score of gen 5000 is 4842
# Lineup: [1631367, 1630541, 1630611, 1626168, 1629643, 1630193, 1641713, 1630183], Score: 36190
# Lineup: [1630227, 203078, 1630556, 1629675, 1630192, 1631241, 1641771, 1630591], Score: 35176
# Lineup: [1630259, 1628379, 1629006, 1630587, 203939, 1630284, 1626168, 1630183], Score: 35005
# Lineup: [1630702, 1641754, 1631220, 1641771, 1630643, 1629003, 1627783, 1630193], Score: 33243
# Lineup: [1630162, 1630639, 1641724, 1628966, 1626168, 202709, 1627884, 1641723], Score: 31372
# ECOSYSTEM 19
# Best score of gen 250 is 4950
# Best score of gen 500 is 4877
# Best score of gen 750 is 4794
# Best score of gen 1000 is 4769
# Best score of gen 1250 is 4691
# Best score of gen 1500 is 4941
# Best score of gen 1750 is 4935
# Best score of gen 2000 is 4820
# Best score of gen 2250 is 4822
# Best score of gen 2500 is 4896
# Best score of gen 2750 is 4810
# Best score of gen 3000 is 4861
# Best score of gen 3250 is 4937
# Best score of gen 3500 is 4857
# Best score of gen 3750 is 4731
# Best score of gen 4000 is 4921
# Best score of gen 4250 is 4807
# Best score of gen 4500 is 4807
# Best score of gen 4750 is 4796
# Best score of gen 5000 is 4863
# Lineup: [1630177, 1631111, 1629010, 1630180, 203939, 1631367, 1629002, 1630230], Score: 34392
# Lineup: [203552, 1628972, 1629726, 1630611, 1630604, 1641722, 1630583, 201580], Score: 33513
# Lineup: [1630184, 1628370, 203200, 1628995, 1628963, 1641724, 1641713, 1630702], Score: 33368
# Lineup: [1631093, 1641754, 1630556, 1628449, 1630164, 202709, 1631222, 1631367], Score: 30245
# Lineup: [203935, 1631220, 1630587, 1630296, 1630164, 1631241, 1641711, 1627742], Score: 24971
